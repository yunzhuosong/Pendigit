# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %pylab inline

import sklearn as sk
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Read data
df=pd.read_fwf('pendigits_training.txt')
#check number of rows and columns in dataset
df.shape
# Out:
# (7493, 17)

# %%
#rename columns.
df.columns=['feature_a','feature_b','feature_c','feature_d','feature_e','feature_f','feature_g','feature_h','feature_i','feature_j','feature_k','feature_l','feature_m','feature_n','feature_o','feature_p','class']
df.head()
# Out:
#    feature_a  feature_b  feature_c  feature_d  feature_e  feature_f  \
# 0          0         89         27        100         42         75
# 1          0         57         31         68         72         90
# 2          0        100          7         92          5         68
# 3          0         67         49         83        100        100
# 4        100        100         88         99         49         74
#
#    feature_g  feature_h  feature_i  feature_j  feature_k  feature_l  \
# 0         29         45         15         15         37          0
# 1        100        100         76         75         50         51
# 2         19         45         86         34        100         45
# 3         81         80         60         60         40         40
# 4         17         47          0         16         37          0
#
#    feature_m  feature_n  feature_o  feature_p  class
# 0         69          2        100          6      2
# ...

# %%
#Split up data into input and target('class').
x_train=df.drop(columns='class')
x_train.head()
# Out:
#    feature_a  feature_b  feature_c  feature_d  feature_e  feature_f  \
# 0          0         89         27        100         42         75
# 1          0         57         31         68         72         90
# 2          0        100          7         92          5         68
# 3          0         67         49         83        100        100
# 4        100        100         88         99         49         74
#
#    feature_g  feature_h  feature_i  feature_j  feature_k  feature_l  \
# 0         29         45         15         15         37          0
# 1        100        100         76         75         50         51
# 2         19         45         86         34        100         45
# 3         81         80         60         60         40         40
# 4         17         47          0         16         37          0
#
#    feature_m  feature_n  feature_o  feature_p
# 0         69          2        100          6
# 1         28         25         16          0
# ...

# %%
y_train=df['class'].values
y_train
# Out:
# array([2, 1, 4, ..., 5, 1, 7], dtype=int64)

# %%
#Name feature columns of training data as cols.
distance_cols=['feature_a','feature_b','feature_c','feature_d','feature_e','feature_f','feature_g','feature_h','feature_i','feature_j','feature_k','feature_l','feature_m','feature_n','feature_o','feature_p']
cols=df[distance_cols]
#Normalize training data.F(v) = (v - mean) / std using mean and std of each dimension.
x_train_norm=(cols - cols.mean()) / cols.std()
x_train_norm
# Out:
#       feature_a  feature_b  feature_c  feature_d  feature_e  feature_f  \
# 0     -1.121803   0.256561  -0.495379   0.871199  -0.254155   0.363507
# 1     -1.121803  -1.642705  -0.343041  -0.758139   0.604719   0.911407
# 2     -1.121803   0.909434  -1.257071   0.463864  -1.313432   0.107820
# 3     -1.121803  -1.049184   0.342482   0.005613   1.406335   1.276674
# 4      1.879032   0.909434   1.827780   0.820282  -0.053751   0.326980
# ...         ...        ...        ...        ...        ...        ...
# 7488  -1.121803  -0.158903  -1.180901  -1.216390   0.146653  -1.134087
# 7489   0.348606   0.909434  -1.523663  -0.656306  -0.769479  -0.330500
# 7490   1.879032   0.790730   0.761412   0.871199  -0.769479   0.801827
# 7491   0.648690  -1.167888   1.942034   0.871199   0.948269   1.130567
# 7492  -1.121803  -0.396311  -0.419210   0.871199   1.234560   0.765300
#
#       feature_g  feature_h  feature_i  feature_j  feature_k  feature_l  \
# ...

# %%
#read test data.
df1=pd.read_fwf('pendigits_test.txt')
#rename test data columns.
df1.columns=['feature_a','feature_b','feature_c','feature_d','feature_e','feature_f','feature_g','feature_h','feature_i','feature_j','feature_k','feature_l','feature_m','feature_n','feature_o','feature_p','class']
df1.head()
# Out:
#    feature_a  feature_b  feature_c  feature_d  feature_e  feature_f  \
# 0         80        100         18         98         60         66
# 1          0         94          9         57         20         19
# 2         95         82         71        100         27         77
# 3         68        100          6         88         47         75
# 4         70        100        100         97         70         81
#
#    feature_g  feature_h  feature_i  feature_j  feature_k  feature_l  \
# 0        100         29         42          0          0         23
# 1          7          0         20         36         70         68
# 2         77         73        100         80         93         42
# 3         87         82         85         56        100         29
# 4         45         65         30         49         20         33
#
#    feature_m  feature_n  feature_o  feature_p  class
# 0         42         61         56         98      8
# ...

# %%
#Check number of rows and columns of test data.
df1.shape
# Out:
# (3497, 17)

# %%
#split input and target class for test data.
x_test=df1.drop(columns='class')
x_test.head()
# Out:
#    feature_a  feature_b  feature_c  feature_d  feature_e  feature_f  \
# 0         80        100         18         98         60         66
# 1          0         94          9         57         20         19
# 2         95         82         71        100         27         77
# 3         68        100          6         88         47         75
# 4         70        100        100         97         70         81
#
#    feature_g  feature_h  feature_i  feature_j  feature_k  feature_l  \
# 0        100         29         42          0          0         23
# 1          7          0         20         36         70         68
# 2         77         73        100         80         93         42
# 3         87         82         85         56        100         29
# 4         45         65         30         49         20         33
#
#    feature_m  feature_n  feature_o  feature_p
# 0         42         61         56         98
# 1        100        100         18         92
# ...

# %%
#Name feature columns of test data as cols1.
cols1=df1[distance_cols]
#Normalize test data. Apply mean of training data cols.mean() and std of training data cols.std() for each dimension.
x_test_norm=(cols1 - cols.mean()) / cols.std()
x_test_norm
# Out:
#       feature_a  feature_b  feature_c  feature_d  feature_e  feature_f  \
# 0      1.278865   0.909434  -0.838140   0.769365   0.261170   0.034767
# 1     -1.121803   0.553322  -1.180901  -1.318224  -0.883995  -1.681987
# 2      1.728990  -0.158903   1.180342   0.871199  -0.683592   0.436560
# 3      0.918765   0.909434  -1.295155   0.260197  -0.111009   0.363507
# 4      0.978781   0.909434   2.284795   0.718448   0.547461   0.582667
# ...         ...        ...        ...        ...        ...        ...
# 3492  -0.041502   0.909434  -0.609633  -0.656306  -1.456578  -0.987980
# 3493  -0.641669  -0.574368   0.037805   0.871199   0.032137  -0.038286
# 3494   0.558665   0.909434  -0.495379  -0.198054  -1.456578  -0.951453
# 3495  -0.551644   0.909434  -1.523663  -1.114557  -1.370691  -1.535880
# 3496   0.018514   0.909434  -0.114533  -0.096221  -1.113029  -0.367027
#
#       feature_g  feature_h  feature_i  feature_j  feature_k  feature_l  \
# ...

# %%
x_test.shape
# Out:
# (3497, 16)

# %%
y_test=df1['class'].values
y_test
# Out:
# array([8, 8, 9, ..., 0, 0, 4], dtype=int64)

# %%
from sklearn import metrics
from sklearn.neighbors import KNeighborsClassifier

# %%
#Use KNN. Find optimal K.
#Trying possible Ks from 1 to 20.
possibleKs = list(range(1,20))
#Create a list to hold accuracy scores for all Ks.
accuracy_scores = [ ]

#Train and test knn model for all possible Ks, and append each accuracy score to accuracy_score list.
for K in possibleKs:
    knn = KNeighborsClassifier(n_neighbors = K)
    knn.fit(x_train_norm,y_train)
    y_pred=knn.predict(x_test_norm)
    scores = metrics.accuracy_score(y_test, y_pred)
    accuracy_scores.append(scores.mean())
    
#Determine optimal K: The K that miximizes the accuracy score of knn model.
optimal_k = neighbors[accuracy_scores.index(max(accuracy_scores))]
print('Optimal k is',optimal_k,'accuracy is',max(accuracy_scores))
# Out:
# Optimal k is 4 accuracy is 0.976551329711181
